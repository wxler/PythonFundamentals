# %% [markdown]
# # 1. anaconda简介

# %% [markdown]
# - 进入官网
# https://www.anaconda.com
# - 点解download进入下载页面
# - 按步骤安装
# - 启动相关应用
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. jupyter lab 基本操作

# %% [markdown]
# ## 2.1. jupyter lab 简介

# %% [markdown]
# - JupyterLab包含了Jupyter Notebook所有功能。
# - JupyterLab作为一种基于web的集成开发环境，你可以使用它编写notebook、操作终端、编辑markdown文本、打开交互模式、查看csv文件及图片等功能

# %% [markdown]
# ## 2.2. jupyter lab 基本操作

# %% [markdown]
# ### 2.2.1 操作模式

# %% [markdown]
# 两种操作模式 `command  mode`  和  `edit  mode`

# %% [markdown]
# 在一个`cell`中按下`enter`就进入edit  mode，按下`Esc`进入command  mode

# %% [markdown]
# ### 2.2.2 cell转换类型

# %% [markdown]
# - code:代码环境
# - markdown: 带有latex公式输入的增强markdown
# - raw：纯文本

# %% [markdown]
# **cell类型转换方式**
#
# - 鼠标操作
# - 快捷键
#
# command模式下：m:markdown r:raw text y:code

# %% [markdown]
# ### 2.2.3 运行cell

# %% [markdown]
# - shift+enter:运行并跳转到下一个cell
# - control+enter：运行并停留在当前cell

# %% [markdown]
# ### 2.2.4 增加/删除cell

# %% [markdown]
# - 鼠标操作：两种模式均可
# - 快捷键：a/d command模式
#
#
# 1. A 在当前cell的上面添加cell
# 2. B 在当前cell的下面添加cell
# 3. 双击D  快速删除当前cell

# %% [markdown]
# ### 2.2.5 代码提示功能

# %% [markdown]
# - tab 代码补全或缩进
# - Shift-Tab 提示
# - 更多快捷键参照 [Jupyter Notebook骚操作](https://mp.weixin.qq.com/s?__biz=MzU5MjI3NzIxMw==&mid=2247488276&idx=2&sn=696900f0744474486eece7dee706e31e&chksm=fe2368a6c954e1b01e7e5943b697c1aec840aba995446230d9c6dc385f8471750002539a5921&mpshare=1&scene=24&srcid=&sharer_sharetime=1591664539198&sharer_shareid=18383980e942ee6dfd94ea4b7b61fcbe&ascene=14&devicetype=android-29&version=27000f3d&nettype=WIFI&abtest_cookie=AAACAA%3D%3D&lang=zh_CN&exportkey=AX%2BZM%2BDxUN6bs5k3X3SQbQY%3D&pass_ticket=njbcV9rUgIhNR7K4XdDWqfGsAPAcyPs1nE8Eoab4vyjmTWneMPO%2FDwraZRwPmQxP&wx_header=1)

# %% [markdown]
# ### 2.2.6 注释多行代码
# - ctrl / 注释多行代码

# %% [markdown]
# ### 2.2.6 运行py文件
# ```python
# % run path/filename
# ```

# %%
# %run C:\Users\wang1\Desktop\学习笔记\压缩文件zip\go\go.py
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\Desktop\学习笔记\压缩文件zip\go\go.py in <module>
#     202
#     203
# --> 204 main()
#
# ~\Desktop\学习笔记\压缩文件zip\go\go.py in main()
#     196     page0()
#     197     clear_all()
# --> 198     page1()
#     199     clear_all()
#     200     page2()
#
# ~\Desktop\学习笔记\压缩文件zip\go\go.py in page1()
#     163 def page1():
#     164     turtle.speed(10)
# --> 165     draw_people(-250, 20)
#     166     turtle.penup()
#     167     turtle.goto(-150, -30)
#
# ~\Desktop\学习笔记\压缩文件zip\go\go.py in draw_people(x, y)
#     111     turtle.pensize(4)
#     112     turtle.pendown()
# --> 113     turtle.circle(2, 360)
#     114     turtle.setheading(0)
#     115     turtle.penup()
#
# D:\install\anaconda3\lib\turtle.py in circle(radius, extent, steps)
#
# D:\install\anaconda3\lib\turtle.py in circle(self, radius, extent, steps)
#    1990             self.speed(speed)
#    1991             self._go(l)
# -> 1992             self.speed(0)
#    1993             self._rotate(w)
#    1994         self._rotate(-w2)
#
# D:\install\anaconda3\lib\turtle.py in speed(self, speed)
#    2172         else:
#    2173             speed = 0
# -> 2174         self.pen(speed=speed)
#    2175
#    2176     def color(self, *args):
#
# D:\install\anaconda3\lib\turtle.py in pen(self, pen, **pendict)
#    2457             self._shapetrafo = ( scx*ca, scy*(shf*ca + sa),
#    2458                                 -scx*sa, scy*(ca - shf*sa))
# -> 2459         self._update()
#    2460
#    2461 ## three dummy methods to be implemented by child class:
#
# D:\install\anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# D:\install\anaconda3\lib\turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# D:\install\anaconda3\lib\turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:

# %% [markdown]
# ### 2.2.7 Markdown标题级别

# %% [markdown]
# - 命令行模式下，1 2 3 4 5 6分别是1-6级标题

# %% [markdown]
# ### 2.2.8 cell加行号

# %% [markdown]
# - 命令行模式下，shilt+L为所有cell加上行号，L不持支给单个cell加行号
# - 鼠标点击view显示行号

# %% [markdown]
# ### 2.2.9 cell合并分割

# %% [markdown]
# - 编辑模式，`crtl shift - 在光标处分割cell`
# - 命令行模式 `shift 鼠标 选中多个cell`
# `shift m 合并选中给的cell`

# %% [markdown]
# # 3. 插件安装

# %% [markdown]
# - 查看已安装插件：`jupyter labextension list`

# %% [markdown]
# ## 3.1. Jupyter Notebook目录插件

# %% [markdown]
# https://www.jianshu.com/p/f314e9868cae

# %% [markdown]
# ## 3.2. Jupyter lab目录插件

# %% [markdown]
# https://www.pinggu.com/post/details/5eccf61a7fba3d625f75771d

# %% [markdown]
# ## 3.3. jupyterlab_code_formatter–代码pep8

# %% [markdown]
# https://www.brothereye.cn/python/362/

# %% [markdown]
# **jupyterlab_code_formatter官网**
# - https://github.com/ryantam626/jupyterlab_code_formatter

# %% [markdown]
# ## 3.4. 超级好用15个Jupyter Lab插件

# %% [markdown]
# https://zhuanlan.zhihu.com/p/101070029

# %% [markdown]
# ## 3.5. 工具篇-Jupyter Lab效率提升插件

# %% [markdown]
# https://zhuanlan.zhihu.com/p/73374773

# %% [markdown]
# ## 3.6. 解决build失败问题

# %% [markdown]
# 终止JupyterLab后，在命令行下输入`jupyter-lab build`
